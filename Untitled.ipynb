# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.Series(data=[0.87, 0.92, 0.69 , 0.88 ],
               index=['Viola–Jones','d-lib',' 99 parts','146 parts'],
               name="age").rename_axis("age", axis=0)

x = df.index
y = df.values
plt.xlabel('recognition method')
plt.ylabel('precision')
plt.title("Precision Estimation")
plt.bar(x, y,color=['blue','red','green','green'])
# Out:
# <BarContainer object of 4 artists>
