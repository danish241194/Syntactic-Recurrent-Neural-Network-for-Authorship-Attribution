# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import nltk 
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize, sent_tokenize 
import os
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
stop_words = set(stopwords.words('english')) 
import numpy as np
from keras.models import Sequential
from keras.layers import Embedding
from keras.layers import Input
from keras.models import Model
from keras import optimizers
from keras.layers import concatenate,CuDNNLSTM
from keras import initializers
from keras import backend as K
import random

from keras.layers import Dense, LSTM,Dropout, Activation,Bidirectional,Reshape,Permute,Multiply,Flatten,Lambda,Layer,TimeDistributed,CuDNNLSTM
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# Using TensorFlow backend.

# %%
def SentenceToPOS(sentences):
    data = []
    for sentence in sentences: 
        one_sentence_pos = [] 
        
        wordsList = nltk.word_tokenize(sentence)
        
        wordsList = [w for w in wordsList if not w in stop_words]

        tagged = nltk.pos_tag(wordsList)
        
        for val in tagged:
            one_sentence_pos.append(val[1])
        data.append(one_sentence_pos)
    return data

def Fianl_X_and_Y(novelPOS, novelLabel, sentenceSize):
    i, X, Y = 0, [], []
    for novel in novelPOS:
        start, end = 0, sentenceSize
        while(end <= len(novel)):
            X.append(novel[start:end])
            Y.append(novelLabel[i])
            start = end
            end += sentenceSize 
        i += 1
    return X, Y

def Get_X_and_Y_In_POS_Form(fullPath, sentenceSize):
    filenameList = os.listdir(fullPath)
    filenameList.sort()
    
    novelPOS, novelLabel, fileNumber = [], [], 1
    for filename in filenameList:
        print(fileNumber,"/",len(filenameList)," Done")
        fileNumber += 1
        Path = fullPath + filename
        with open(Path, 'r') as f:
            data = f.read().replace('"\n"','').replace('\n',' ').replace('- ','')
            sentences = sent_tokenize(data)
            POS = SentenceToPOS(sentences)
            novelPOS.append(POS)
            novelLabel.append(filename[8])
    return Fianl_X_and_Y(novelPOS, novelLabel, sentenceSize)

# %%
print("Preprocessing Phase 1 : Fetching data")
print(".....................................")

X, Y = Get_X_and_Y_In_POS_Form('/content/gdrive/My Drive/dataset/',100)

print("Preprocessing Phase 1 : Finished\n\n")
# Out:
# Preprocessing Phase 1 : Fetching data
# .....................................
# 1 / 33  Done
# 2 / 33  Done
# 3 / 33  Done
# 4 / 33  Done
# 5 / 33  Done
# 6 / 33  Done
# 7 / 33  Done
# 8 / 33  Done
# 9 / 33  Done
# 10 / 33  Done
# 11 / 33  Done
# 12 / 33  Done
# 13 / 33  Done
# 14 / 33  Done
# 15 / 33  Done
# 16 / 33  Done
# 17 / 33  Done
# 18 / 33  Done
# 19 / 33  Done
# 20 / 33  Done
# 21 / 33  Done
# 22 / 33  Done
# 23 / 33  Done
# 24 / 33  Done
# 25 / 33  Done
# 26 / 33  Done
# 27 / 33  Done
# 28 / 33  Done
# 29 / 33  Done
# 30 / 33  Done
# 31 / 33  Done
# 32 / 33  Done
# 33 / 33  Done
# Preprocessing Phase 1 : Finished

# %%
maxval, minval = 0, 999999
for doc in X:
  for sentence in doc:
    minval = min(minval, len(sentence))
    maxval = max(maxval, len(sentence))
print(maxval, minval)
# Out:
# 155 1

# %%
Labels = np.unique(Y, return_counts = True)[0]

# %%
LabelCount = {}
for label in Labels:
  LabelCount[label] = 0

# %%
MIN_VAL = min(np.unique(Y,return_counts=True)[1]) + 200

# %%
def dataBalancing(X, Y, LabelCount, MIN_VAL):
  X_data = []
  for i in range(len(X)):
      if(LabelCount[Y[i]] < MIN_VAL):
          X_data.append([X[i],Y[i]])
          LabelCount[Y[i]] += 1

  random.shuffle(X_data)

  new_X = []
  new_Y = []
  for m ,n in X_data:
    new_X.append(m)
    new_Y.append(n)

  return new_X, new_Y

# %%
X, Y = dataBalancing(X, Y, LabelCount, MIN_VAL)

# %%
def tag_to_index_dictionary(X):
    tag = set([])
    for doc in X:
        for sentence in doc:
            for word in sentence:
                tag.add(word)
    tag2index = {t: i + 1 for i, t in enumerate(list(tag))}
    tag2index['-PAD-'] = 0
    return tag2index

def convert_tag_to_sequence_numbers(X, tag2index):
    new_X=[]
    for doc in X:
        new_S = []
        for sentence in doc:
            new_W = []
            for word in sentence:
                new_W.append(tag2index[word])
            new_S.append(new_W)
        new_X.append(new_S)
    return new_X


def pad_zeros_to_sequence(X, max_length):
    new_X = []
    for doc in X:
        new_X.append(pad_sequences(doc, maxlen=max_length, padding='post'))
    return new_X

def Encode_Labels(Y):
    le = LabelEncoder()
    return le.fit_transform(Y)

# %%
tag2index = tag_to_index_dictionary(X)
DICTIONARY_LENGTH = len(tag2index)
MAX_LENGTH = 30 # why 30 only ?
SENTENCES_IN_NOVEL = 100

X = convert_tag_to_sequence_numbers(X, tag2index)
X = pad_zeros_to_sequence(X, MAX_LENGTH)
X = np.array(X)
TOTAL_ROWS = X.shape[0]

# %%
# My Code Above

# %%
A = [[[[1,2,3],[4,5,6],[7,8,9]],['A']],[[[12,2,3],[42,5,6],[72,8,9]],['B']],[[[11,2,3],[41,5,6],[71,8,9]],['C']]]
random.shuffle(A)
A
# Out:
# [[[[11, 2, 3], [41, 5, 6], [71, 8, 9]], ['C']],
#  [[[12, 2, 3], [42, 5, 6], [72, 8, 9]], ['B']],
#  [[[1, 2, 3], [4, 5, 6], [7, 8, 9]], ['A']]]

# %%
real_X = []
for i in range(SENTENCES_IN_NOVEL):
    real_X.append(list())
for i in range(SENTENCES_IN_NOVEL):
    for j in range(TOTAL_ROWS):
        real_X[i].append(X[j][i])

X_train = []
for i in range(SENTENCES_IN_NOVEL):
    X_train.append(np.array(real_X[i]))

Y = Encode_Labels(Y) 
from tensorflow.keras.utils import to_categorical
y_binary = to_categorical(Y)

# %%
np.array(y_binary).shape
# Out:
# (1803, 14)

# %%
from keras.engine.topology import Layer as LL
class Attention(LL):
    def __init__(self, step_dim,
                 W_regularizer=None, b_regularizer=None,
                 W_constraint=None, b_constraint=None,
                 bias=True, **kwargs):
        self.supports_masking = True
        self.init = initializers.get('glorot_uniform')

        self.W_regularizer = regularizers.get(W_regularizer)
        self.b_regularizer = regularizers.get(b_regularizer)

        self.W_constraint = constraints.get(W_constraint)
        self.b_constraint = constraints.get(b_constraint)

        self.bias = bias
        self.step_dim = step_dim
        self.features_dim = 0
        super(Attention, self).__init__(**kwargs)

    def build(self, input_shape):
        assert len(input_shape) == 3
        print(self.W_constraint)
        self.W = self.add_weight((input_shape[-1],),
                                 initializer=self.init,
                                 name='{}_W'.format(self.name),
                                 regularizer=self.W_regularizer,
                                 constraint=self.W_constraint)
        self.features_dim = input_shape[-1]

        if self.bias:
            self.b = self.add_weight((input_shape[1],),
                                     initializer='zero',
                                     name='{}_b'.format(self.name),
                                     regularizer=self.b_regularizer,
                                     constraint=self.b_constraint)
        else:
            self.b = None

        self.built = True

    def compute_mask(self, input, input_mask=None):
        return None

    def call(self, x, mask=None):
        features_dim = self.features_dim
        step_dim = self.step_dim

        eij = K.reshape(K.dot(K.reshape(x, (-1, features_dim)),
                        K.reshape(self.W, (features_dim, 1))), (-1, step_dim))
        print(eij.shape,self.b.shape)

        if self.bias:
            eij += self.b

        eij = K.tanh(eij)

        a = K.exp(eij)

        if mask is not None:
            a *= K.cast(mask, K.floatx())

        a /= K.cast(K.sum(a, axis=1, keepdims=True) + K.epsilon(), K.floatx())

        a = K.expand_dims(a)
        weighted_input = x * a
        return K.sum(weighted_input, axis=1)

    def compute_output_shape(self, input_shape):
        return input_shape[0],  self.features_dim

# %%
from keras import  regularizers,constraints,initializers
from keras.layers import GlobalAveragePooling1D, GlobalMaxPooling1D, concatenate, SpatialDropout1D
from keras.layers import Dense,Input,LSTM,Bidirectional,Activation,Conv1D,GRU

model = Sequential() 

FIRST_LSTM = 256
SECOND_LSTM = 256
EMBEDD_VECTOR_LENGTH = 128
outputs=[]
inputs_=[]
EMB = Embedding(DICTIONARY_LENGTH, EMBEDD_VECTOR_LENGTH, input_length=30)

# BDR1 = SpatialDropout1D(0.2)
BDR2 = Bidirectional(GRU(FIRST_LSTM, return_sequences=True,dropout=0.1,recurrent_dropout=0.1))
BDR3 = Conv1D(FIRST_LSTM, kernel_size = 3, padding = "valid", kernel_initializer = "glorot_uniform")
BDR4 = GlobalAveragePooling1D()
BDR5 = GlobalMaxPooling1D()


# BDR = Bidirectional(CuDNNLSTM(FIRST_LSTM,return_sequences=True),merge_mode='concat')
TDB = TimeDistributed(Dense(DICTIONARY_LENGTH+3))
for i in range(SENTENCES_IN_NOVEL): # SENTENCES_IN_NOVEL = 100
    if(i % 10 == 0):
      print(i,"/",SENTENCES_IN_NOVEL)
    inputlayer = Input(shape=[MAX_LENGTH]) # MAX_LENGTH = 30 (30 words per sentence)
    inputs_.append(inputlayer)
    layer = EMB(inputlayer) # 50 is embedd vector size for each POS Tag
#     layer =  BDR1(layer) # output 100 because of bidirectonal concat
    layer =  BDR2(layer)
    layer =  BDR3(layer)
    avg_pool =  BDR4(layer)
    max_pool =  BDR5(layer)
    layer = concatenate([avg_pool, max_pool])
    outputs.append(layer)

merge_ = concatenate(outputs)
print(np.array(outputs).shape)
merge_ = Reshape((SENTENCES_IN_NOVEL, 2*FIRST_LSTM), input_shape=(SENTENCES_IN_NOVEL*(2*FIRST_LSTM),))(merge_)
merge_ = Bidirectional(CuDNNLSTM(SECOND_LSTM,return_sequences=True),merge_mode='concat')(merge_)

attention_mul = Attention(100)(merge_)#step_dimen =100
output = Dense(14, activation='softmax')(attention_mul)

model = Model(inputs=inputs_,outputs=output)
model.summary()
# Out:
# 0 / 100
# 10 / 100
# 20 / 100
# 30 / 100
# 40 / 100
# 50 / 100
# 60 / 100
# 70 / 100
# 80 / 100
# 90 / 100
# (100,)
# None
# (?, 100) (100,)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_372 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_373 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_374 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_375 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_376 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_377 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_378 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_379 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_380 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_381 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_382 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_383 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_384 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_385 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_386 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_387 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_388 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_389 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_390 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_391 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_392 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_393 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_394 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_395 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_396 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_397 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_398 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_399 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_400 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_401 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_402 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_403 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_404 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_405 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_406 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_407 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_408 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_409 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_410 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_411 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_412 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_413 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_414 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_415 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_416 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_417 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_418 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_419 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_420 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_421 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_422 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_423 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_424 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_425 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_426 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_427 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_428 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_429 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_430 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_431 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_432 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_433 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_434 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_435 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_436 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_437 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_438 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_439 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_440 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_441 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_442 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_443 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_444 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_445 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_446 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_447 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_448 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_449 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_450 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_451 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_452 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_453 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_454 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_455 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_456 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_457 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_458 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_459 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_460 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_461 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_462 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_463 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_464 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_465 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_466 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_467 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_468 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_469 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_470 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# input_471 (InputLayer)          (None, 30)           0
# __________________________________________________________________________________________________
# embedding_8 (Embedding)         (None, 30, 128)      5888        input_372[0][0]
#                                                                  input_373[0][0]
#                                                                  input_374[0][0]
#                                                                  input_375[0][0]
#                                                                  input_376[0][0]
#                                                                  input_377[0][0]
#                                                                  input_378[0][0]
#                                                                  input_379[0][0]
#                                                                  input_380[0][0]
#                                                                  input_381[0][0]
#                                                                  input_382[0][0]
#                                                                  input_383[0][0]
#                                                                  input_384[0][0]
#                                                                  input_385[0][0]
#                                                                  input_386[0][0]
#                                                                  input_387[0][0]
#                                                                  input_388[0][0]
#                                                                  input_389[0][0]
#                                                                  input_390[0][0]
#                                                                  input_391[0][0]
#                                                                  input_392[0][0]
#                                                                  input_393[0][0]
#                                                                  input_394[0][0]
#                                                                  input_395[0][0]
#                                                                  input_396[0][0]
#                                                                  input_397[0][0]
#                                                                  input_398[0][0]
#                                                                  input_399[0][0]
#                                                                  input_400[0][0]
#                                                                  input_401[0][0]
#                                                                  input_402[0][0]
#                                                                  input_403[0][0]
#                                                                  input_404[0][0]
#                                                                  input_405[0][0]
#                                                                  input_406[0][0]
#                                                                  input_407[0][0]
#                                                                  input_408[0][0]
#                                                                  input_409[0][0]
#                                                                  input_410[0][0]
#                                                                  input_411[0][0]
#                                                                  input_412[0][0]
#                                                                  input_413[0][0]
#                                                                  input_414[0][0]
#                                                                  input_415[0][0]
#                                                                  input_416[0][0]
#                                                                  input_417[0][0]
#                                                                  input_418[0][0]
#                                                                  input_419[0][0]
#                                                                  input_420[0][0]
#                                                                  input_421[0][0]
#                                                                  input_422[0][0]
#                                                                  input_423[0][0]
#                                                                  input_424[0][0]
#                                                                  input_425[0][0]
#                                                                  input_426[0][0]
#                                                                  input_427[0][0]
#                                                                  input_428[0][0]
#                                                                  input_429[0][0]
#                                                                  input_430[0][0]
#                                                                  input_431[0][0]
#                                                                  input_432[0][0]
#                                                                  input_433[0][0]
#                                                                  input_434[0][0]
#                                                                  input_435[0][0]
#                                                                  input_436[0][0]
#                                                                  input_437[0][0]
#                                                                  input_438[0][0]
#                                                                  input_439[0][0]
#                                                                  input_440[0][0]
#                                                                  input_441[0][0]
#                                                                  input_442[0][0]
#                                                                  input_443[0][0]
#                                                                  input_444[0][0]
#                                                                  input_445[0][0]
#                                                                  input_446[0][0]
#                                                                  input_447[0][0]
#                                                                  input_448[0][0]
#                                                                  input_449[0][0]
#                                                                  input_450[0][0]
#                                                                  input_451[0][0]
#                                                                  input_452[0][0]
#                                                                  input_453[0][0]
#                                                                  input_454[0][0]
#                                                                  input_455[0][0]
#                                                                  input_456[0][0]
#                                                                  input_457[0][0]
#                                                                  input_458[0][0]
#                                                                  input_459[0][0]
#                                                                  input_460[0][0]
#                                                                  input_461[0][0]
#                                                                  input_462[0][0]
#                                                                  input_463[0][0]
#                                                                  input_464[0][0]
#                                                                  input_465[0][0]
#                                                                  input_466[0][0]
#                                                                  input_467[0][0]
#                                                                  input_468[0][0]
#                                                                  input_469[0][0]
#                                                                  input_470[0][0]
#                                                                  input_471[0][0]
# __________________________________________________________________________________________________
# bidirectional_10 (Bidirectional (None, 30, 512)      591360      embedding_8[0][0]
#                                                                  embedding_8[1][0]
#                                                                  embedding_8[2][0]
#                                                                  embedding_8[3][0]
#                                                                  embedding_8[4][0]
#                                                                  embedding_8[5][0]
#                                                                  embedding_8[6][0]
#                                                                  embedding_8[7][0]
#                                                                  embedding_8[8][0]
#                                                                  embedding_8[9][0]
#                                                                  embedding_8[10][0]
#                                                                  embedding_8[11][0]
#                                                                  embedding_8[12][0]
#                                                                  embedding_8[13][0]
#                                                                  embedding_8[14][0]
#                                                                  embedding_8[15][0]
#                                                                  embedding_8[16][0]
#                                                                  embedding_8[17][0]
#                                                                  embedding_8[18][0]
#                                                                  embedding_8[19][0]
#                                                                  embedding_8[20][0]
#                                                                  embedding_8[21][0]
#                                                                  embedding_8[22][0]
#                                                                  embedding_8[23][0]
#                                                                  embedding_8[24][0]
#                                                                  embedding_8[25][0]
#                                                                  embedding_8[26][0]
#                                                                  embedding_8[27][0]
#                                                                  embedding_8[28][0]
#                                                                  embedding_8[29][0]
#                                                                  embedding_8[30][0]
#                                                                  embedding_8[31][0]
#                                                                  embedding_8[32][0]
#                                                                  embedding_8[33][0]
#                                                                  embedding_8[34][0]
#                                                                  embedding_8[35][0]
#                                                                  embedding_8[36][0]
#                                                                  embedding_8[37][0]
#                                                                  embedding_8[38][0]
#                                                                  embedding_8[39][0]
#                                                                  embedding_8[40][0]
#                                                                  embedding_8[41][0]
#                                                                  embedding_8[42][0]
#                                                                  embedding_8[43][0]
#                                                                  embedding_8[44][0]
#                                                                  embedding_8[45][0]
#                                                                  embedding_8[46][0]
#                                                                  embedding_8[47][0]
#                                                                  embedding_8[48][0]
#                                                                  embedding_8[49][0]
#                                                                  embedding_8[50][0]
#                                                                  embedding_8[51][0]
#                                                                  embedding_8[52][0]
#                                                                  embedding_8[53][0]
#                                                                  embedding_8[54][0]
#                                                                  embedding_8[55][0]
#                                                                  embedding_8[56][0]
#                                                                  embedding_8[57][0]
#                                                                  embedding_8[58][0]
#                                                                  embedding_8[59][0]
#                                                                  embedding_8[60][0]
#                                                                  embedding_8[61][0]
#                                                                  embedding_8[62][0]
#                                                                  embedding_8[63][0]
#                                                                  embedding_8[64][0]
#                                                                  embedding_8[65][0]
#                                                                  embedding_8[66][0]
#                                                                  embedding_8[67][0]
#                                                                  embedding_8[68][0]
#                                                                  embedding_8[69][0]
#                                                                  embedding_8[70][0]
#                                                                  embedding_8[71][0]
#                                                                  embedding_8[72][0]
#                                                                  embedding_8[73][0]
#                                                                  embedding_8[74][0]
#                                                                  embedding_8[75][0]
#                                                                  embedding_8[76][0]
#                                                                  embedding_8[77][0]
#                                                                  embedding_8[78][0]
#                                                                  embedding_8[79][0]
#                                                                  embedding_8[80][0]
#                                                                  embedding_8[81][0]
#                                                                  embedding_8[82][0]
#                                                                  embedding_8[83][0]
#                                                                  embedding_8[84][0]
#                                                                  embedding_8[85][0]
#                                                                  embedding_8[86][0]
#                                                                  embedding_8[87][0]
#                                                                  embedding_8[88][0]
#                                                                  embedding_8[89][0]
#                                                                  embedding_8[90][0]
#                                                                  embedding_8[91][0]
#                                                                  embedding_8[92][0]
#                                                                  embedding_8[93][0]
#                                                                  embedding_8[94][0]
#                                                                  embedding_8[95][0]
#                                                                  embedding_8[96][0]
#                                                                  embedding_8[97][0]
#                                                                  embedding_8[98][0]
#                                                                  embedding_8[99][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 28, 256)      393472      bidirectional_10[0][0]
#                                                                  bidirectional_10[1][0]
#                                                                  bidirectional_10[2][0]
#                                                                  bidirectional_10[3][0]
#                                                                  bidirectional_10[4][0]
#                                                                  bidirectional_10[5][0]
#                                                                  bidirectional_10[6][0]
#                                                                  bidirectional_10[7][0]
#                                                                  bidirectional_10[8][0]
#                                                                  bidirectional_10[9][0]
#                                                                  bidirectional_10[10][0]
#                                                                  bidirectional_10[11][0]
#                                                                  bidirectional_10[12][0]
#                                                                  bidirectional_10[13][0]
#                                                                  bidirectional_10[14][0]
#                                                                  bidirectional_10[15][0]
#                                                                  bidirectional_10[16][0]
#                                                                  bidirectional_10[17][0]
#                                                                  bidirectional_10[18][0]
#                                                                  bidirectional_10[19][0]
#                                                                  bidirectional_10[20][0]
#                                                                  bidirectional_10[21][0]
#                                                                  bidirectional_10[22][0]
#                                                                  bidirectional_10[23][0]
#                                                                  bidirectional_10[24][0]
#                                                                  bidirectional_10[25][0]
#                                                                  bidirectional_10[26][0]
#                                                                  bidirectional_10[27][0]
#                                                                  bidirectional_10[28][0]
#                                                                  bidirectional_10[29][0]
#                                                                  bidirectional_10[30][0]
#                                                                  bidirectional_10[31][0]
#                                                                  bidirectional_10[32][0]
#                                                                  bidirectional_10[33][0]
#                                                                  bidirectional_10[34][0]
#                                                                  bidirectional_10[35][0]
#                                                                  bidirectional_10[36][0]
#                                                                  bidirectional_10[37][0]
#                                                                  bidirectional_10[38][0]
#                                                                  bidirectional_10[39][0]
#                                                                  bidirectional_10[40][0]
#                                                                  bidirectional_10[41][0]
#                                                                  bidirectional_10[42][0]
#                                                                  bidirectional_10[43][0]
#                                                                  bidirectional_10[44][0]
#                                                                  bidirectional_10[45][0]
#                                                                  bidirectional_10[46][0]
#                                                                  bidirectional_10[47][0]
#                                                                  bidirectional_10[48][0]
#                                                                  bidirectional_10[49][0]
#                                                                  bidirectional_10[50][0]
#                                                                  bidirectional_10[51][0]
#                                                                  bidirectional_10[52][0]
#                                                                  bidirectional_10[53][0]
#                                                                  bidirectional_10[54][0]
#                                                                  bidirectional_10[55][0]
#                                                                  bidirectional_10[56][0]
#                                                                  bidirectional_10[57][0]
#                                                                  bidirectional_10[58][0]
#                                                                  bidirectional_10[59][0]
#                                                                  bidirectional_10[60][0]
#                                                                  bidirectional_10[61][0]
#                                                                  bidirectional_10[62][0]
#                                                                  bidirectional_10[63][0]
#                                                                  bidirectional_10[64][0]
#                                                                  bidirectional_10[65][0]
#                                                                  bidirectional_10[66][0]
#                                                                  bidirectional_10[67][0]
#                                                                  bidirectional_10[68][0]
#                                                                  bidirectional_10[69][0]
#                                                                  bidirectional_10[70][0]
#                                                                  bidirectional_10[71][0]
#                                                                  bidirectional_10[72][0]
#                                                                  bidirectional_10[73][0]
#                                                                  bidirectional_10[74][0]
#                                                                  bidirectional_10[75][0]
#                                                                  bidirectional_10[76][0]
#                                                                  bidirectional_10[77][0]
# ...
#                                                                  global_max_pooling1d_6[83][0]
# __________________________________________________________________________________________________
# concatenate_255 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[84][0]
#                                                                  global_max_pooling1d_6[84][0]
# __________________________________________________________________________________________________
# concatenate_256 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[85][0]
#                                                                  global_max_pooling1d_6[85][0]
# __________________________________________________________________________________________________
# concatenate_257 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[86][0]
#                                                                  global_max_pooling1d_6[86][0]
# __________________________________________________________________________________________________
# concatenate_258 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[87][0]
#                                                                  global_max_pooling1d_6[87][0]
# __________________________________________________________________________________________________
# concatenate_259 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[88][0]
#                                                                  global_max_pooling1d_6[88][0]
# __________________________________________________________________________________________________
# concatenate_260 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[89][0]
#                                                                  global_max_pooling1d_6[89][0]
# __________________________________________________________________________________________________
# concatenate_261 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[90][0]
#                                                                  global_max_pooling1d_6[90][0]
# __________________________________________________________________________________________________
# concatenate_262 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[91][0]
#                                                                  global_max_pooling1d_6[91][0]
# __________________________________________________________________________________________________
# concatenate_263 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[92][0]
#                                                                  global_max_pooling1d_6[92][0]
# __________________________________________________________________________________________________
# concatenate_264 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[93][0]
#                                                                  global_max_pooling1d_6[93][0]
# __________________________________________________________________________________________________
# concatenate_265 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[94][0]
#                                                                  global_max_pooling1d_6[94][0]
# __________________________________________________________________________________________________
# concatenate_266 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[95][0]
#                                                                  global_max_pooling1d_6[95][0]
# __________________________________________________________________________________________________
# concatenate_267 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[96][0]
#                                                                  global_max_pooling1d_6[96][0]
# __________________________________________________________________________________________________
# concatenate_268 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[97][0]
#                                                                  global_max_pooling1d_6[97][0]
# __________________________________________________________________________________________________
# concatenate_269 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[98][0]
#                                                                  global_max_pooling1d_6[98][0]
# __________________________________________________________________________________________________
# concatenate_270 (Concatenate)   (None, 512)          0           global_average_pooling1d_6[99][0]
#                                                                  global_max_pooling1d_6[99][0]
# __________________________________________________________________________________________________
# concatenate_271 (Concatenate)   (None, 51200)        0           concatenate_171[0][0]
#                                                                  concatenate_172[0][0]
#                                                                  concatenate_173[0][0]
#                                                                  concatenate_174[0][0]
#                                                                  concatenate_175[0][0]
#                                                                  concatenate_176[0][0]
#                                                                  concatenate_177[0][0]
#                                                                  concatenate_178[0][0]
#                                                                  concatenate_179[0][0]
#                                                                  concatenate_180[0][0]
#                                                                  concatenate_181[0][0]
#                                                                  concatenate_182[0][0]
#                                                                  concatenate_183[0][0]
#                                                                  concatenate_184[0][0]
#                                                                  concatenate_185[0][0]
#                                                                  concatenate_186[0][0]
#                                                                  concatenate_187[0][0]
#                                                                  concatenate_188[0][0]
#                                                                  concatenate_189[0][0]
#                                                                  concatenate_190[0][0]
#                                                                  concatenate_191[0][0]
#                                                                  concatenate_192[0][0]
#                                                                  concatenate_193[0][0]
#                                                                  concatenate_194[0][0]
#                                                                  concatenate_195[0][0]
#                                                                  concatenate_196[0][0]
#                                                                  concatenate_197[0][0]
#                                                                  concatenate_198[0][0]
#                                                                  concatenate_199[0][0]
#                                                                  concatenate_200[0][0]
#                                                                  concatenate_201[0][0]
#                                                                  concatenate_202[0][0]
#                                                                  concatenate_203[0][0]
#                                                                  concatenate_204[0][0]
#                                                                  concatenate_205[0][0]
#                                                                  concatenate_206[0][0]
#                                                                  concatenate_207[0][0]
#                                                                  concatenate_208[0][0]
#                                                                  concatenate_209[0][0]
#                                                                  concatenate_210[0][0]
#                                                                  concatenate_211[0][0]
#                                                                  concatenate_212[0][0]
#                                                                  concatenate_213[0][0]
#                                                                  concatenate_214[0][0]
#                                                                  concatenate_215[0][0]
#                                                                  concatenate_216[0][0]
#                                                                  concatenate_217[0][0]
#                                                                  concatenate_218[0][0]
#                                                                  concatenate_219[0][0]
#                                                                  concatenate_220[0][0]
#                                                                  concatenate_221[0][0]
#                                                                  concatenate_222[0][0]
#                                                                  concatenate_223[0][0]
#                                                                  concatenate_224[0][0]
#                                                                  concatenate_225[0][0]
#                                                                  concatenate_226[0][0]
#                                                                  concatenate_227[0][0]
#                                                                  concatenate_228[0][0]
#                                                                  concatenate_229[0][0]
#                                                                  concatenate_230[0][0]
#                                                                  concatenate_231[0][0]
#                                                                  concatenate_232[0][0]
#                                                                  concatenate_233[0][0]
#                                                                  concatenate_234[0][0]
#                                                                  concatenate_235[0][0]
#                                                                  concatenate_236[0][0]
#                                                                  concatenate_237[0][0]
#                                                                  concatenate_238[0][0]
#                                                                  concatenate_239[0][0]
#                                                                  concatenate_240[0][0]
#                                                                  concatenate_241[0][0]
#                                                                  concatenate_242[0][0]
#                                                                  concatenate_243[0][0]
#                                                                  concatenate_244[0][0]
#                                                                  concatenate_245[0][0]
#                                                                  concatenate_246[0][0]
#                                                                  concatenate_247[0][0]
#                                                                  concatenate_248[0][0]
#                                                                  concatenate_249[0][0]
#                                                                  concatenate_250[0][0]
#                                                                  concatenate_251[0][0]
#                                                                  concatenate_252[0][0]
#                                                                  concatenate_253[0][0]
#                                                                  concatenate_254[0][0]
#                                                                  concatenate_255[0][0]
#                                                                  concatenate_256[0][0]
#                                                                  concatenate_257[0][0]
#                                                                  concatenate_258[0][0]
#                                                                  concatenate_259[0][0]
#                                                                  concatenate_260[0][0]
#                                                                  concatenate_261[0][0]
#                                                                  concatenate_262[0][0]
#                                                                  concatenate_263[0][0]
#                                                                  concatenate_264[0][0]
#                                                                  concatenate_265[0][0]
#                                                                  concatenate_266[0][0]
#                                                                  concatenate_267[0][0]
#                                                                  concatenate_268[0][0]
#                                                                  concatenate_269[0][0]
#                                                                  concatenate_270[0][0]
# __________________________________________________________________________________________________
# reshape_4 (Reshape)             (None, 100, 512)     0           concatenate_271[0][0]
# __________________________________________________________________________________________________
# bidirectional_11 (Bidirectional (None, 100, 512)     1576960     reshape_4[0][0]
# __________________________________________________________________________________________________
# attention_3 (Attention)         (None, 512)          612         bidirectional_11[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 14)           7182        attention_3[0][0]
# ==================================================================================================
# Total params: 2,575,474
# Trainable params: 2,575,474
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
 np.array([1,2,3,4,5,6]).reshape(2,3)
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
np.array(X_train).shape
# Out:
# (100, 1803, 30)

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Nadam(lr=0.001),
              metrics=['accuracy'])
history = model.fit(X_train, y_binary, epochs=30, validation_split=0.1)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Train on 1622 samples, validate on 181 samples
# Epoch 1/30
# 1622/1622 [==============================] - 667s 411ms/step - loss: 2.3538 - acc: 0.2004 - val_loss: 1.8278 - val_acc: 0.3039
# Epoch 2/30
# 1622/1622 [==============================] - 471s 290ms/step - loss: 1.6760 - acc: 0.3588 - val_loss: 1.5446 - val_acc: 0.4309
# Epoch 3/30
# 1622/1622 [==============================] - 467s 288ms/step - loss: 1.4282 - acc: 0.4593 - val_loss: 1.6867 - val_acc: 0.4033
# Epoch 4/30
# 1622/1622 [==============================] - 459s 283ms/step - loss: 1.2442 - acc: 0.5351 - val_loss: 1.2469 - val_acc: 0.5304
# Epoch 5/30
# 1622/1622 [==============================] - 451s 278ms/step - loss: 1.1314 - acc: 0.5734 - val_loss: 1.0913 - val_acc: 0.5967
# Epoch 6/30
# 1622/1622 [==============================] - 452s 279ms/step - loss: 1.0215 - acc: 0.6097 - val_loss: 1.1883 - val_acc: 0.5304
# Epoch 7/30
# 1622/1622 [==============================] - 452s 278ms/step - loss: 0.9032 - acc: 0.6806 - val_loss: 1.0811 - val_acc: 0.6077
# Epoch 8/30
# 1622/1622 [==============================] - 451s 278ms/step - loss: 0.8462 - acc: 0.6948 - val_loss: 0.8266 - val_acc: 0.6740
# Epoch 9/30
# 1622/1622 [==============================] - 452s 279ms/step - loss: 0.7003 - acc: 0.7546 - val_loss: 1.0451 - val_acc: 0.6354
# Epoch 10/30
# 1622/1622 [==============================] - 453s 280ms/step - loss: 0.6285 - acc: 0.7663 - val_loss: 0.8501 - val_acc: 0.7017
# Epoch 11/30
# 1622/1622 [==============================] - 452s 279ms/step - loss: 0.5004 - acc: 0.8335 - val_loss: 0.7052 - val_acc: 0.7238
# Epoch 12/30
# 1622/1622 [==============================] - 454s 280ms/step - loss: 0.4221 - acc: 0.8607 - val_loss: 0.5035 - val_acc: 0.8011
# Epoch 13/30
# 1622/1622 [==============================] - 454s 280ms/step - loss: 0.3425 - acc: 0.8909 - val_loss: 0.6911 - val_acc: 0.7569
# Epoch 14/30
# 1622/1622 [==============================] - 452s 278ms/step - loss: 0.3005 - acc: 0.9026 - val_loss: 0.4181 - val_acc: 0.8287
# Epoch 15/30
# 1622/1622 [==============================] - 456s 281ms/step - loss: 0.1974 - acc: 0.9414 - val_loss: 0.4078 - val_acc: 0.8508
# Epoch 16/30
# 1622/1622 [==============================] - 453s 280ms/step - loss: 0.1592 - acc: 0.9544 - val_loss: 0.5474 - val_acc: 0.8122
# Epoch 17/30
# 1622/1622 [==============================] - 455s 280ms/step - loss: 0.1237 - acc: 0.9686 - val_loss: 0.3155 - val_acc: 0.8785
# Epoch 18/30
# 1622/1622 [==============================] - 456s 281ms/step - loss: 0.0810 - acc: 0.9815 - val_loss: 0.9125 - val_acc: 0.7127
# Epoch 19/30
# 1622/1622 [==============================] - 457s 282ms/step - loss: 0.1532 - acc: 0.9519 - val_loss: 0.2483 - val_acc: 0.9171
# Epoch 20/30
# 1622/1622 [==============================] - 456s 281ms/step - loss: 0.0330 - acc: 0.9975 - val_loss: 0.2206 - val_acc: 0.9227
# Epoch 21/30
# 1622/1622 [==============================] - 463s 285ms/step - loss: 0.0126 - acc: 1.0000 - val_loss: 0.2062 - val_acc: 0.9171
# Epoch 22/30
# 1622/1622 [==============================] - 464s 286ms/step - loss: 0.0071 - acc: 1.0000 - val_loss: 0.2105 - val_acc: 0.9337
# Epoch 23/30
# 1622/1622 [==============================] - 461s 284ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.2160 - val_acc: 0.9171
# Epoch 24/30
# 1622/1622 [==============================] - 465s 286ms/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.2176 - val_acc: 0.9171
# Epoch 25/30
# 1622/1622 [==============================] - 468s 289ms/step - loss: 0.0029 - acc: 1.0000 - val_loss: 0.2145 - val_acc: 0.9227
# Epoch 26/30
# 1622/1622 [==============================] - 464s 286ms/step - loss: 0.0024 - acc: 1.0000 - val_loss: 0.2189 - val_acc: 0.9171
# Epoch 27/30
#  896/1622 [===============>..............] - ETA: 3:52 - loss: 0.0020 - acc: 1.0000

# %%
import pandas as pd
import matplotlib.pyplot as plt
hist = pd.DataFrame(history.history)
plt.figure(figsize=(12,12))
plt.plot(hist["acc"])
plt.plot(hist["val_acc"])
plt.show()

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.Nadam(lr=0.001),
              metrics=['accuracy'])
history2 = model.fit(X_train,y_binary,batch_size=16, epochs=30,validation_split=0.1)

# %%
hist = pd.DataFrame(history.history)
plt.figure(figsize=(12,12))
plt.plot(hist["acc"],label = "Training Accuracy")
plt.plot(hist["val_acc"],label = "Validation Accuracy")
plt.title('Epoc Number Vs Accuracy') 
plt.xlabel('Epoc Number') 
# naming the y axis 
plt.ylabel('Accuracy')   
# show a legend on the plot 
plt.legend() 
plt.show()
