# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.Series(data=[ 0.60, 0.71,.85, .91],
               index=['Viola–Jones','d-lib',' 99 parts','146 parts model'],
               name="age").rename_axis("age", axis=0)

x = df.index
y = df.values
plt.xlabel('recognition method')
plt.ylabel('recognition rate')
plt.title("Face recognition rate")
plt.bar(x, y)
# Out:
# <BarContainer object of 4 artists>
